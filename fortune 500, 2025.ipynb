# %%
import os
import numpy as np
import pandas as pd
import requests
from bs4 import BeautifulSoup
import matplotlib.pyplot as plt
import seaborn as sns
# %pip install html5lib
import html5lib
# !pip install lxml html5lib beautifulsoup4
import lxml
import statistics
# Out:
# ...
#
# ...

# %%
url="https://www.fortuneindia.com/rankings/fortune-500/2025"

# %%
url
# Out:
# 'https://www.fortuneindia.com/rankings/fortune-500/2025'

# %%
page=requests.get(url)

# %%
page
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(page.text)
soup
# Out:
# <!DOCTYPE html>
# <html class="" lang="en">
# <head>
# <link crossorigin="" href="https://assets.fortuneindia.com" rel="preconnect"/>
# <link crossorigin="" href="https://media.fortuneindia.com" rel="preconnect"/>
# <meta content="@FortuneIndia" name="twitter:site"/>
# <meta content="https://www.fortuneindia.com" name="twitter:domain"/>
# <meta content="1113250065862572" property="fb:app_id"/>
# <meta content="Fortune India" property="og:site_name"/>
# <meta content="Fortune India 500 2025: This Year's Top Performing Companies - Fortune India" property="og:title"/>
# <meta content="https://media.fortuneindia.com/fortune-india/2025-07-03/rx21zgga/Fortune500Desktop.png?auto=format,compress&amp;format=webp&amp;w=1200&amp;h=675&amp;dpr=1.0&amp;q=90&amp;fit=cover" property="og:image"/>
# <meta content="1200" property="og:height"/>
# <meta content="675" property="og:width"/>
# ...

# %%
company=soup.find("table",class_="table")
company=soup.find("table",class_="G6MF8")
print(company)
# Out:
# <table class="G6MF8"><thead><tr><td class="f3PIy"></td><td class="f3PIy"></td><td class="GBF9K h2OgJ"><span>Remove</span><i class="wtn4h"></i></td><td class="GBF9K h2OgJ"><span>Remove</span><i class="wtn4h"></i></td><td class="GBF9K h2OgJ"><span>Remove</span><i class="wtn4h"></i></td><td class="GBF9K h2OgJ"><span>Remove</span><i class="wtn4h"></i></td><td class="GBF9K h2OgJ"><span>Remove</span><i class="wtn4h"></i></td><td class="GBF9K h2OgJ"><span>Remove</span><i class="wtn4h"></i></td><td class="GBF9K h2OgJ"><span>Remove</span><i class="wtn4h"></i></td><td class="GBF9K h2OgJ"><span>Remove</span><i class="wtn4h"></i></td><td class="GBF9K h2OgJ"><span>Remove</span><i class="wtn4h"></i></td><td class="GBF9K h2OgJ"><span>Remove</span><i class="wtn4h"></i></td><td class="GBF9K h2OgJ"><span>Remove</span><i class="wtn4h"></i></td><td class="GBF9K h2OgJ"><span>Remove</span><i class="wtn4h"></i></td><td class="GBF9K h2OgJ"><span>Remove</span><i class="wtn4h"></i></td><td class="GBF9K h2OgJ"
# ...

# %%
table=pd.read_html(str(company))[0]
table
# Out:
#     Unnamed: 0_level_0                                 Unnamed: 1_level_0  \
#                   RANK                                  COMPANY/OWNERSHIP
# 0                   10                   Reliance IndustriesMukesh Ambani
# 1                   20                                   LICGovt of India
# 2                   30                Indian Oil CorporationGovt of India
# 3                  4+1                   State Bank of IndiaGovt of India
# 4                  5-1                                  ONGCGovt of India
# ..                 ...                                                ...
# 495              496+2                      Route MobileS.K. & R.K. Gupta
# 496             497-16       Himadri Speciality ChemicalSadashiv K Shetty
# 497             498-72  Rajasthan Rajya Vidyut Prasaran Nigam ^Govt of...
# 498         499R-E ‘23             Indo Rama Synthetics (India)O.P. Lohia
# 499             500-18                            Tetra-Pak India ^^ ^MNC
#
# ...

# %%
table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 16 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   (Unnamed: 0_level_0, RANK)               500 non-null    object
#  1   (Unnamed: 1_level_0, COMPANY/OWNERSHIP)  500 non-null    object
#  2   (Remove, INDUSTRY)                       500 non-null    object
#  3   (Remove, TOTAL INCOME (INR Cr))          500 non-null    object
#  4   (Remove, NET OPERATING INCOME (INR Cr))  500 non-null    object
#  5   (Remove, PROFIT (INR Cr))                500 non-null    object
#  6   (Remove, Profit as % of Revenue)         500 non-null    object
#  7   (Remove, cash & bank balance (INR Cr))   500 non-null    int64
#  8   (Remove, total debt (INR Cr))            500 non-null    int64
#  9   (Remove, debt-equity ratio)              500 non-null    object
# ...

# %%
os.getcwd()
# Out:
# 'C:\\Users\\bandu\\python full course'

# %%
table.to_csv("C:\\Users\\bandu\\python full course\\fortune500",index=False)

# %%
company=pd.read_csv('fortune500')
company
# Out:
#     Unnamed: 0_level_0                                 Unnamed: 1_level_0  \
# 0                 RANK                                  COMPANY/OWNERSHIP
# 1                   10                   Reliance IndustriesMukesh Ambani
# 2                   20                                   LICGovt of India
# 3                   30                Indian Oil CorporationGovt of India
# 4                  4+1                   State Bank of IndiaGovt of India
# ..                 ...                                                ...
# 496              496+2                      Route MobileS.K. & R.K. Gupta
# 497             497-16       Himadri Speciality ChemicalSadashiv K Shetty
# 498             498-72  Rajasthan Rajya Vidyut Prasaran Nigam ^Govt of...
# 499         499R-E ‘23             Indo Rama Synthetics (India)O.P. Lohia
# 500             500-18                            Tetra-Pak India ^^ ^MNC
#
#                    Remove               Remove.1  \
# ...

# %%
company.columns=[company.columns,company.iloc[0]]
company=company[1:]
company.head()
# Out:
#   Unnamed: 0_level_0                   Unnamed: 1_level_0            Remove  \
# 0               RANK                    COMPANY/OWNERSHIP          INDUSTRY
# 1                 10     Reliance IndustriesMukesh Ambani         Oil & Gas
# 2                 20                     LICGovt of India  Insurance - Life
# 3                 30  Indian Oil CorporationGovt of India         Oil & Gas
# 4                4+1     State Bank of IndiaGovt of India             Banks
# 5                5-1                    ONGCGovt of India         Oil & Gas
#
#                Remove.1                      Remove.2        Remove.3  \
# 0 TOTAL INCOME (INR Cr) NET OPERATING INCOME (INR Cr) PROFIT (INR Cr)
# 1           9977958.22%                   9646937.06%      696480.04%
# 2            8934653.8%                    8899705.2%      4832018.1%
# 3          766008-1.85%                  758106-2.35%    13598-67.41%
# 4          66334311.57%                  49093811.78%     7756115.62%
# ...

# %%
company.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 1 to 500
# Data columns (total 16 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   (Unnamed: 0_level_0, RANK)                 500 non-null    object
#  1   (Unnamed: 1_level_0, COMPANY/OWNERSHIP)    500 non-null    object
#  2   (Remove, INDUSTRY)                         500 non-null    object
#  3   (Remove.1, TOTAL INCOME (INR Cr))          500 non-null    object
#  4   (Remove.2, NET OPERATING INCOME (INR Cr))  500 non-null    object
#  5   (Remove.3, PROFIT (INR Cr))                500 non-null    object
#  6   (Remove.4, Profit as % of Revenue)         500 non-null    object
#  7   (Remove.5, cash & bank balance (INR Cr))   500 non-null    object
#  8   (Remove.6, total debt (INR Cr))            500 non-null    object
#  9   (Remove.7, debt-equity ratio)              500 non-null    object
# ...

# %%
company.isnull().sum()
# Out:
# Unnamed: 0_level_0  RANK                             0
# Unnamed: 1_level_0  COMPANY/OWNERSHIP                0
# Remove              INDUSTRY                         0
# Remove.1            TOTAL INCOME (INR Cr)            0
# Remove.2            NET OPERATING INCOME (INR Cr)    0
# Remove.3            PROFIT (INR Cr)                  0
# Remove.4            Profit as % of Revenue           0
# Remove.5            cash & bank balance (INR Cr)     0
# Remove.6            total debt (INR Cr)              0
# Remove.7            debt-equity ratio                0
# Remove.8            TOTAL ASSETS (INR Cr)            0
# Remove.9            NET WORTH (INR Cr)               0
# Remove.10           RONW%                            0
# Remove.11           ROCE%                            0
# Remove.12           EMPLOYEES (IN NOS.)              0
# Remove.13           MARKET CAP (INR Cr)              0
# dtype: int64

# %%
company['Unnamed: 0_level_0']=company['Unnamed: 0_level_0'].fillna(0)
# Out:
# C:\Users\bandu\AppData\Local\Temp\ipykernel_23720\3416979981.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   company['Unnamed: 0_level_0']=company['Unnamed: 0_level_0'].fillna(0)

# %%
company['Unnamed: 0_level_0']
# Out:
# 0          RANK
# 1            10
# 2            20
# 3            30
# 4           4+1
# 5           5-1
# ..          ...
# 496       496+2
# 497      497-16
# 498      498-72
# 499  499R-E ‘23
# 500      500-18
#
# [500 rows x 1 columns]

# %%
company['Unnamed: 0_level_0'].isnull().sum()
# Out:
# 0
# RANK    0
# dtype: int64

# %%
company.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 1 to 500
# Data columns (total 16 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   (Unnamed: 0_level_0, RANK)                 500 non-null    object
#  1   (Unnamed: 1_level_0, COMPANY/OWNERSHIP)    500 non-null    object
#  2   (Remove, INDUSTRY)                         500 non-null    object
#  3   (Remove.1, TOTAL INCOME (INR Cr))          500 non-null    object
#  4   (Remove.2, NET OPERATING INCOME (INR Cr))  500 non-null    object
#  5   (Remove.3, PROFIT (INR Cr))                500 non-null    object
#  6   (Remove.4, Profit as % of Revenue)         500 non-null    object
#  7   (Remove.5, cash & bank balance (INR Cr))   500 non-null    object
#  8   (Remove.6, total debt (INR Cr))            500 non-null    object
#  9   (Remove.7, debt-equity ratio)              500 non-null    object
# ...

# %%
company
# Out:
#     Unnamed: 0_level_0                                 Unnamed: 1_level_0  \
# 0                 RANK                                  COMPANY/OWNERSHIP
# 1                   10                   Reliance IndustriesMukesh Ambani
# 2                   20                                   LICGovt of India
# 3                   30                Indian Oil CorporationGovt of India
# 4                  4+1                   State Bank of IndiaGovt of India
# 5                  5-1                                  ONGCGovt of India
# ..                 ...                                                ...
# 496              496+2                      Route MobileS.K. & R.K. Gupta
# 497             497-16       Himadri Speciality ChemicalSadashiv K Shetty
# 498             498-72  Rajasthan Rajya Vidyut Prasaran Nigam ^Govt of...
# 499         499R-E ‘23             Indo Rama Synthetics (India)O.P. Lohia
# 500             500-18                            Tetra-Pak India ^^ ^MNC
#
# ...

# %%
company.to_csv("C:\\Users\\bandu\\python full course\\fortune500 1.0",index=False)

# %%
df=pd.read_csv('fortune500 1.0')

# %%
df
# Out:
#     Unnamed: 0_level_0                                 Unnamed: 1_level_0  \
# 0                 RANK                                  COMPANY/OWNERSHIP
# 1                   10                   Reliance IndustriesMukesh Ambani
# 2                   20                                   LICGovt of India
# 3                   30                Indian Oil CorporationGovt of India
# 4                  4+1                   State Bank of IndiaGovt of India
# ..                 ...                                                ...
# 496              496+2                      Route MobileS.K. & R.K. Gupta
# 497             497-16       Himadri Speciality ChemicalSadashiv K Shetty
# 498             498-72  Rajasthan Rajya Vidyut Prasaran Nigam ^Govt of...
# 499         499R-E ‘23             Indo Rama Synthetics (India)O.P. Lohia
# 500             500-18                            Tetra-Pak India ^^ ^MNC
#
#                    Remove               Remove.1  \
# ...

# %%
df=df.drop(0)

# %%
df
# Out:
#     Unnamed: 0_level_0                                 Unnamed: 1_level_0  \
# 1                   10                   Reliance IndustriesMukesh Ambani
# 2                   20                                   LICGovt of India
# 3                   30                Indian Oil CorporationGovt of India
# 4                  4+1                   State Bank of IndiaGovt of India
# 5                  5-1                                  ONGCGovt of India
# ..                 ...                                                ...
# 496              496+2                      Route MobileS.K. & R.K. Gupta
# 497             497-16       Himadri Speciality ChemicalSadashiv K Shetty
# 498             498-72  Rajasthan Rajya Vidyut Prasaran Nigam ^Govt of...
# 499         499R-E ‘23             Indo Rama Synthetics (India)O.P. Lohia
# 500             500-18                            Tetra-Pak India ^^ ^MNC
#
#                    Remove      Remove.1      Remove.2      Remove.3 Remove.4  \
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0_level_0', 'Unnamed: 1_level_0', 'Remove', 'Remove.1',
#        'Remove.2', 'Remove.3', 'Remove.4', 'Remove.5', 'Remove.6', 'Remove.7',
#        'Remove.8', 'Remove.9', 'Remove.10', 'Remove.11', 'Remove.12',
#        'Remove.13'],
#       dtype='object')

# %%
new_columns={'Unnamed: 0_level_0':'Rank','Unnamed: 1_level_0':'Company/Ownership','Remove':'Industry', 'Remove.1':'Total_income(INR)','Remove.2':'Net_income(INR)','Remove.3':'Profit(INR)','Remove.4':'Profit % of Revenue','Remove.5':'Cash & Bank balance', 'Remove.6':'Total Debt','Remove.7':'Debt equity ratio','Remove.8':'Total Assets','Remove.9':'Net worth','Remove.10':'RONW', 'Remove.11':'ROCE','Remove.12':'Employees','Remove.13':'Marketcap'}

# %%
df.rename(columns=new_columns,inplace=True)

# %%
df
# Out:
#            Rank                                  Company/Ownership  \
# 1            10                   Reliance IndustriesMukesh Ambani
# 2            20                                   LICGovt of India
# 3            30                Indian Oil CorporationGovt of India
# 4           4+1                   State Bank of IndiaGovt of India
# 5           5-1                                  ONGCGovt of India
# ..          ...                                                ...
# 496       496+2                      Route MobileS.K. & R.K. Gupta
# 497      497-16       Himadri Speciality ChemicalSadashiv K Shetty
# 498      498-72  Rajasthan Rajya Vidyut Prasaran Nigam ^Govt of...
# 499  499R-E ‘23             Indo Rama Synthetics (India)O.P. Lohia
# 500      500-18                            Tetra-Pak India ^^ ^MNC
#
#                  Industry Total_income(INR) Net_income(INR)   Profit(INR)  \
# 1               Oil & Gas       9977958.22%     9646937.06%    696480.04%
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 1 to 500
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Rank                 500 non-null    object
#  1   Company/Ownership    500 non-null    object
#  2   Industry             500 non-null    object
#  3   Total_income(INR)    500 non-null    object
#  4   Net_income(INR)      500 non-null    object
#  5   Profit(INR)          500 non-null    object
#  6   Profit % of Revenue  500 non-null    object
#  7   Cash & Bank balance  500 non-null    object
#  8   Total Debt           500 non-null    object
#  9   Debt equity ratio    500 non-null    object
#  10  Total Assets         500 non-null    object
#  11  Net worth            500 non-null    object
#  12  RONW                 500 non-null    object
#  13  ROCE                 500 non-null    object
#  14  Employees            500 non-null    object
# ...

# %%
df.describe()
# Out:
#        Rank                 Company/Ownership Industry Total_income(INR)  \
# count   500                               500      500               500
# unique  500                               500       75               500
# top      10  Reliance IndustriesMukesh Ambani    Banks       9977958.22%
# freq      1                                 1       41                 1
#
#        Net_income(INR) Profit(INR) Profit % of Revenue Cash & Bank balance  \
# count              500         500                 500                 500
# unique             500         500                 408                 466
# top        9646937.06%  696480.04%                 NAP                  65
# freq                 1           1                  37                   3
#
#        Total Debt Debt equity ratio Total Assets Net worth RONW ROCE  \
# count         500               500          500       500  500  500
# unique        463               144          500       493  436  443
# ...

# %%
# Clean up column names (remove extra spaces or newlines)
df.columns = [col.strip() for col in df.columns]

# %%
df
# Out:
#            Rank                                  Company/Ownership  \
# 1            10                   Reliance IndustriesMukesh Ambani
# 2            20                                   LICGovt of India
# 3            30                Indian Oil CorporationGovt of India
# 4           4+1                   State Bank of IndiaGovt of India
# 5           5-1                                  ONGCGovt of India
# ..          ...                                                ...
# 496       496+2                      Route MobileS.K. & R.K. Gupta
# 497      497-16       Himadri Speciality ChemicalSadashiv K Shetty
# 498      498-72  Rajasthan Rajya Vidyut Prasaran Nigam ^Govt of...
# 499  499R-E ‘23             Indo Rama Synthetics (India)O.P. Lohia
# 500      500-18                            Tetra-Pak India ^^ ^MNC
#
#                  Industry Total_income(INR) Net_income(INR)   Profit(INR)  \
# 1               Oil & Gas       9977958.22%     9646937.06%    696480.04%
# ...

# %%
percent_columns = [
    'Total_income(INR)', 'Net_income(INR)', 'Profit(INR)', 
    'Profit % of Revenue', 'Total Assets', 'RONW', 'ROCE'
]

# 2. Loop through each column to remove % and convert to numeric
for col in percent_columns:
    # We use .str.replace to remove the %
    # We also use .str.replace(',', '') just in case there are thousands separators
    # We use .strip() to remove any hidden leading/trailing spaces
    df[col] = df[col].astype(str).str.replace('%', '').str.replace(',', '').str.replace(r'[a-zA-Z]', '', regex=True).str.replace(r'[^0-9.]', '', regex=True).str.strip()
    
    # 3. Convert the column to a numeric float
    # errors='coerce' will turn any non-numeric leftovers (like 'NAP') into NaN
    df[col] = pd.to_numeric(df[col], errors='coerce')

# Check the result
print("New Data Types:")
print(df[percent_columns].dtypes)
print("\nCleaned Data Preview:")
print(df[percent_columns].head())
# Out:
# New Data Types:
# Total_income(INR)      float64
# Net_income(INR)        float64
# Profit(INR)            float64
# Profit % of Revenue    float64
# Total Assets           float64
# RONW                   float64
# ROCE                   float64
# dtype: object
#
# Cleaned Data Preview:
#    Total_income(INR)  Net_income(INR)  Profit(INR)  Profit % of Revenue  \
# 1         9977958.22       9646937.06    696480.04                 6.98
# 2         8934653.80       8899705.20   4832018.10                 5.41
# 3         7660081.85       7581062.35   1359867.41                 1.78
# 4        66334311.57      49093811.78   7756115.62                11.69
# 5         6248050.37       6120651.74   3622626.29                 5.80
#
#    Total Assets   RONW   ROCE
# 1    15332039.8   9.87   9.90
# 2    56115896.8  46.03   0.89
# 3     3495247.1   6.61   7.33
# 4    73296978.6  18.66   1.10
# 5     6180782.5  11.23  11.44

# %%
print(df['Profit(INR)'].describe())
# Out:
# count    5.000000e+02
# mean     5.965603e+05
# std      3.180078e+06
# min      1.200000e+01
# 25%      9.996377e+03
# 50%      5.612175e+04
# 75%      2.191368e+05
# max      5.378406e+07
# Name: Profit(INR), dtype: float64

# %%
print(df['Profit(INR)'].unique())
# Out:
# [6.96480040e+05 4.83201810e+06 1.35986741e+06 7.75611562e+06
#  3.62262629e+06 7.07921051e+06 2.78301137e+06 1.33375035e+06
#  5.10291530e+06 1.50371515e+06 4.85535760e+05 1.60015757e+06
#  3.42120000e+04 2.34221254e+06 3.35563494e+07 3.50460240e+05
#  2.67131830e+05 1.29291474e+06 1.49882536e+07 1.45007500e+05
#  2.80556320e+05 3.53585470e+05 2.07161038e+06 1.75401480e+06
#  3.70634120e+05 1.24502577e+06 1.84801029e+07 8.87288900e+04
#  6.08050660e+05 1.80273066e+06 1.73901075e+06 3.80340010e+05
#  2.29911634e+06 2.21262148e+06 2.37222660e+05 3.47476984e+06
#  1.31351892e+06 5.18900000e+03 7.25811190e+05 9.54845450e+05
#  1.12613376e+06 5.64069300e+04 3.97174300e+04 3.33745500e+04
#  5.67218480e+05 1.06493620e+05 7.11211954e+06 1.22672836e+06
#  2.70867800e+04 7.80323780e+05 1.29393788e+06 2.57671310e+05
#  1.09291412e+06 4.25280320e+05 7.32549800e+04 3.97387700e+04
#  7.43211160e+05 3.10725100e+05 2.81252650e+05 1.55210330e+05
# ...

# %%
# Fill empty spots with 0 then convert
df['Total_income(INR)'] = df['Total_income(INR)'].fillna(0).astype(int)

# %%
df['Net_income(INR)'] = df['Net_income(INR)'].fillna(0).astype(int)

# %%
df['Profit(INR)']=df['Profit(INR)'].fillna(0).astype(int)

# %%
df['Profit % of Revenue']=df['Profit % of Revenue'].fillna(0).astype(int)

# %%
df['Total Assets']=df['Total Assets'].fillna(0).astype(int)

# %%
df['RONW']=df['RONW'].fillna(0).astype(int)

# %%
df['ROCE']=df['ROCE'].fillna(0).astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 1 to 500
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Rank                 500 non-null    object
#  1   Company/Ownership    500 non-null    object
#  2   Industry             500 non-null    object
#  3   Total_income(INR)    500 non-null    int32
#  4   Net_income(INR)      500 non-null    int32
#  5   Profit(INR)          500 non-null    int32
#  6   Profit % of Revenue  500 non-null    int32
#  7   Cash & Bank balance  500 non-null    object
#  8   Total Debt           500 non-null    object
#  9   Debt equity ratio    500 non-null    object
#  10  Total Assets         500 non-null    int32
#  11  Net worth            500 non-null    object
#  12  RONW                 500 non-null    int32
#  13  ROCE                 500 non-null    int32
#  14  Employees            500 non-null    object
# ...

# %%
df
# Out:
#            Rank                                  Company/Ownership  \
# 1            10                   Reliance IndustriesMukesh Ambani
# 2            20                                   LICGovt of India
# 3            30                Indian Oil CorporationGovt of India
# 4           4+1                   State Bank of IndiaGovt of India
# 5           5-1                                  ONGCGovt of India
# ..          ...                                                ...
# 496       496+2                      Route MobileS.K. & R.K. Gupta
# 497      497-16       Himadri Speciality ChemicalSadashiv K Shetty
# 498      498-72  Rajasthan Rajya Vidyut Prasaran Nigam ^Govt of...
# 499  499R-E ‘23             Indo Rama Synthetics (India)O.P. Lohia
# 500      500-18                            Tetra-Pak India ^^ ^MNC
#
#                  Industry  Total_income(INR)  Net_income(INR)  Profit(INR)  \
# 1               Oil & Gas            9977958          9646937       696480
# ...

# %%
# 1. Remove the existing 'Rank' column
# We use errors='ignore' just in case the column name has hidden spaces
df.drop(columns=['Rank'], errors='ignore', inplace=True)

# 2. Reset the index to bring the first (unnamed) column into the dataframe
# This creates a new column called 'index'
df = df.reset_index()

# 3. Rename that 'index' column to 'Rank'
df.rename(columns={'index': 'Rank'}, inplace=True)

# 4. (Optional) Adjust the Rank to start from 1 instead of 0 if necessary
df['Rank'] = df['Rank']+0

# View the result
print(df.head())
# Out:
#    Rank                    Company/Ownership          Industry  \
# 0     1     Reliance IndustriesMukesh Ambani         Oil & Gas
# 1     2                     LICGovt of India  Insurance - Life
# 2     3  Indian Oil CorporationGovt of India         Oil & Gas
# 3     4     State Bank of IndiaGovt of India             Banks
# 4     5                    ONGCGovt of India         Oil & Gas
#
#    Total_income(INR)  Net_income(INR)  Profit(INR)  Profit % of Revenue  \
# 0            9977958          9646937       696480                    6
# 1            8934653          8899705      4832018                    5
# 2            7660081          7581062      1359867                    1
# 3           66334311         49093811      7756115                   11
# 4            6248050          6120651      3622626                    5
#
#   Cash & Bank balance Total Debt Debt equity ratio  Total Assets Net worth  \
# ...

# %%
df
# Out:
#      Rank                                  Company/Ownership  \
# 0       1                   Reliance IndustriesMukesh Ambani
# 1       2                                   LICGovt of India
# 2       3                Indian Oil CorporationGovt of India
# 3       4                   State Bank of IndiaGovt of India
# 4       5                                  ONGCGovt of India
# ..    ...                                                ...
# 495   496                      Route MobileS.K. & R.K. Gupta
# 496   497       Himadri Speciality ChemicalSadashiv K Shetty
# 497   498  Rajasthan Rajya Vidyut Prasaran Nigam ^Govt of...
# 498   499             Indo Rama Synthetics (India)O.P. Lohia
# 499   500                            Tetra-Pak India ^^ ^MNC
#
#                  Industry  Total_income(INR)  Net_income(INR)  Profit(INR)  \
# 0               Oil & Gas            9977958          9646937       696480
# 1        Insurance - Life            8934653          8899705      4832018
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Rank                 500 non-null    int64
#  1   Company/Ownership    500 non-null    object
#  2   Industry             500 non-null    object
#  3   Total_income(INR)    500 non-null    int32
#  4   Net_income(INR)      500 non-null    int32
#  5   Profit(INR)          500 non-null    int32
#  6   Profit % of Revenue  500 non-null    int32
#  7   Cash & Bank balance  500 non-null    object
#  8   Total Debt           500 non-null    object
#  9   Debt equity ratio    500 non-null    object
#  10  Total Assets         500 non-null    int32
#  11  Net worth            500 non-null    object
#  12  RONW                 500 non-null    int32
#  13  ROCE                 500 non-null    int32
#  14  Employees            500 non-null    object
# ...

# %%
print(df['Cash & Bank balance'].describe())
# Out:
# count     500
# unique    466
# top        65
# freq        3
# Name: Cash & Bank balance, dtype: object

# %%
print(df['Total Debt'].describe())
# Out:
# count     500
# unique    463
# top         0
# freq       19
# Name: Total Debt, dtype: object

# %%
# 1. Clean the column (remove commas, symbols, and spaces)
df['Cash & Bank balance'] = df['Cash & Bank balance'].astype(str).str.replace(r'[^0-9.-]', '', regex=True)

# 2. Convert to numeric
df['Cash & Bank balance'] = pd.to_numeric(df['Cash & Bank balance'], errors='coerce')

# 3. Fill any empty spots (like where 'NAP' was) with 0
df['Cash & Bank balance'] = df['Cash & Bank balance'].fillna(0)

# Now run describe again - it will look totally different!
print(df['Cash & Bank balance'].describe())
# Out:
# count       500.000000
# mean       7956.526000
# std       28064.926074
# min           3.000000
# 25%         330.750000
# 50%        1011.500000
# 75%        4287.750000
# max      357933.000000
# Name: Cash & Bank balance, dtype: float64

# %%
# 1. List all columns you want to convert to numbers
cols_to_convert = ['Total Debt', 'Debt equity ratio', 'Employees','Marketcap','Net worth']

for col in cols_to_convert:
    # Remove everything except numbers, dots, and minus signs
    # This cleans up commas, currency symbols, and spaces in one go
    df[col] = df[col].astype(str).str.replace(r'[^0-9.-]', '', regex=True)
    
    # Convert the cleaned strings to actual floats
    # 'coerce' turns remaining text like "NAP" into NaN
    df[col] = pd.to_numeric(df[col], errors='coerce')
    
    # Fill empty spots with 0 to keep the data consistent
    df[col] = df[col].fillna(0)

# 2. Now verify that they are all numerical
print(df[cols_to_convert].info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Total Debt         500 non-null    int64
#  1   Debt equity ratio  500 non-null    float64
#  2   Employees          500 non-null    float64
#  3   Marketcap          500 non-null    float64
#  4   Net worth          500 non-null    int64
# dtypes: float64(3), int64(2)
# memory usage: 19.7 KB
# None

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Rank                 500 non-null    int64
#  1   Company/Ownership    500 non-null    object
#  2   Industry             500 non-null    object
#  3   Total_income(INR)    500 non-null    int32
#  4   Net_income(INR)      500 non-null    int32
#  5   Profit(INR)          500 non-null    int32
#  6   Profit % of Revenue  500 non-null    int32
#  7   Cash & Bank balance  500 non-null    int64
#  8   Total Debt           500 non-null    int64
#  9   Debt equity ratio    500 non-null    float64
#  10  Total Assets         500 non-null    int32
#  11  Net worth            500 non-null    int64
#  12  RONW                 500 non-null    int32
#  13  ROCE                 500 non-null    int32
#  14  Employees            500 non-null    float64
# ...

# %%
df.isnull().sum()
# Out:
# Rank                   0
# Company/Ownership      0
# Industry               0
# Total_income(INR)      0
# Net_income(INR)        0
# Profit(INR)            0
# Profit % of Revenue    0
# Cash & Bank balance    0
# Total Debt             0
# Debt equity ratio      0
# Total Assets           0
# Net worth              0
# RONW                   0
# ROCE                   0
# Employees              0
# Marketcap              0
# dtype: int64

# %%
# Shift the index so the first row is labeled '1' instead of '0'
df.index = df.index + 1

# Now when you display df.head(), it will show 1, 2, 3, 4, 5
print(df.head())
# Out:
#    Rank                    Company/Ownership          Industry  \
# 1     1     Reliance IndustriesMukesh Ambani         Oil & Gas
# 2     2                     LICGovt of India  Insurance - Life
# 3     3  Indian Oil CorporationGovt of India         Oil & Gas
# 4     4     State Bank of IndiaGovt of India             Banks
# 5     5                    ONGCGovt of India         Oil & Gas
#
#    Total_income(INR)  Net_income(INR)  Profit(INR)  Profit % of Revenue  \
# 1            9977958          9646937       696480                    6
# 2            8934653          8899705      4832018                    5
# 3            7660081          7581062      1359867                    1
# 4           66334311         49093811      7756115                   11
# 5            6248050          6120651      3622626                    5
#
#    Cash & Bank balance  Total Debt  Debt equity ratio  Total Assets  \
# 1               106502      374313               0.44      15332039
# ...

# %%
df
# Out:
#      Rank                                  Company/Ownership  \
# 1       1                   Reliance IndustriesMukesh Ambani
# 2       2                                   LICGovt of India
# 3       3                Indian Oil CorporationGovt of India
# 4       4                   State Bank of IndiaGovt of India
# 5       5                                  ONGCGovt of India
# ..    ...                                                ...
# 496   496                      Route MobileS.K. & R.K. Gupta
# 497   497       Himadri Speciality ChemicalSadashiv K Shetty
# 498   498  Rajasthan Rajya Vidyut Prasaran Nigam ^Govt of...
# 499   499             Indo Rama Synthetics (India)O.P. Lohia
# 500   500                            Tetra-Pak India ^^ ^MNC
#
#                  Industry  Total_income(INR)  Net_income(INR)  Profit(INR)  \
# 1               Oil & Gas            9977958          9646937       696480
# 2        Insurance - Life            8934653          8899705      4832018
# ...

# %%
# Replace 'Column_Name' with the exact name you want to delete
df = df.drop('Rank', axis=1)

# %%
df
# Out:
#                                      Company/Ownership              Industry  \
# 1                     Reliance IndustriesMukesh Ambani             Oil & Gas
# 2                                     LICGovt of India      Insurance - Life
# 3                  Indian Oil CorporationGovt of India             Oil & Gas
# 4                     State Bank of IndiaGovt of India                 Banks
# 5                                    ONGCGovt of India             Oil & Gas
# ..                                                 ...                   ...
# 496                      Route MobileS.K. & R.K. Gupta           IT Services
# 497       Himadri Speciality ChemicalSadashiv K Shetty  Speciality Chemicals
# 498  Rajasthan Rajya Vidyut Prasaran Nigam ^Govt of...                 Power
# 499             Indo Rama Synthetics (India)O.P. Lohia              Textiles
# 500                            Tetra-Pak India ^^ ^MNC                 Paper
#
# ...

# %%
# Set the name of the index to 'Rank'
df.index.name = 'Rank'

# Display to see the label above the index
print(df.head())
# Out:
#                         Company/Ownership          Industry  \
# Rank
# 1        Reliance IndustriesMukesh Ambani         Oil & Gas
# 2                        LICGovt of India  Insurance - Life
# 3     Indian Oil CorporationGovt of India         Oil & Gas
# 4        State Bank of IndiaGovt of India             Banks
# 5                       ONGCGovt of India         Oil & Gas
#
#       Total_income(INR)  Net_income(INR)  Profit(INR)  Profit % of Revenue  \
# Rank
# 1               9977958          9646937       696480                    6
# 2               8934653          8899705      4832018                    5
# 3               7660081          7581062      1359867                    1
# 4              66334311         49093811      7756115                   11
# 5               6248050          6120651      3622626                    5
#
#       Cash & Bank balance  Total Debt  Debt equity ratio  Total Assets  \
# Rank
# ...

# %%
df
# Out:
#                                       Company/Ownership              Industry  \
# Rank
# 1                      Reliance IndustriesMukesh Ambani             Oil & Gas
# 2                                      LICGovt of India      Insurance - Life
# 3                   Indian Oil CorporationGovt of India             Oil & Gas
# 4                      State Bank of IndiaGovt of India                 Banks
# 5                                     ONGCGovt of India             Oil & Gas
# ...                                                 ...                   ...
# 496                       Route MobileS.K. & R.K. Gupta           IT Services
# 497        Himadri Speciality ChemicalSadashiv K Shetty  Speciality Chemicals
# 498   Rajasthan Rajya Vidyut Prasaran Nigam ^Govt of...                 Power
# 499              Indo Rama Synthetics (India)O.P. Lohia              Textiles
# 500                             Tetra-Pak India ^^ ^MNC                 Paper
#
# ...

# %% [markdown]
# ### Now its time to visualization

# %%
url1="https://www.fortuneindia.com/fortune-500/company-listing/?year=2022&page=1&query=&per_page=500&page=1"

# %%
url1
# Out:
# 'https://www.fortuneindia.com/fortune-500/company-listing/?year=2022&page=1&query=&per_page=500&page=1'

# %%
page1=requests.get(url1)

# %%
page1
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(page1.text)
soup
# Out:
# <!DOCTYPE html>
# <html class="" lang="en">
# <head>
# <link crossorigin="" href="https://assets.fortuneindia.com" rel="preconnect"/>
# <link crossorigin="" href="https://media.fortuneindia.com" rel="preconnect"/>
# <meta content="@FortuneIndia" name="twitter:site"/>
# <meta content="https://www.fortuneindia.com" name="twitter:domain"/>
# <meta content="1113250065862572" property="fb:app_id"/>
# <meta content="Fortune India" property="og:site_name"/>
# <meta content="Fortune India 500 2022: This Year's Top Performing Companies - Fortune India" property="og:title"/>
# <meta content="https://media.fortuneindia.com/fortune-india/2025-07-03/rx21zgga/Fortune500Desktop.png?auto=format,compress&amp;format=webp&amp;w=1200&amp;h=675&amp;dpr=1.0&amp;q=90&amp;fit=cover" property="og:image"/>
# <meta content="1200" property="og:height"/>
# <meta content="675" property="og:width"/>
# ...

# %%
company1=soup.find("table",class_="table")
company1=soup.find("table",class_="G6MF8")
print(company1)
# Out:
# <table class="G6MF8"><thead><tr><td class="f3PIy"></td><td class="f3PIy"></td><td class="GBF9K h2OgJ"><span>Remove</span><i class="wtn4h"></i></td><td class="GBF9K h2OgJ"><span>Remove</span><i class="wtn4h"></i></td><td class="GBF9K h2OgJ"><span>Remove</span><i class="wtn4h"></i></td><td class="GBF9K h2OgJ"><span>Remove</span><i class="wtn4h"></i></td><td class="GBF9K h2OgJ"><span>Remove</span><i class="wtn4h"></i></td><td class="GBF9K h2OgJ"><span>Remove</span><i class="wtn4h"></i></td><td class="GBF9K h2OgJ"><span>Remove</span><i class="wtn4h"></i></td><td class="GBF9K h2OgJ"><span>Remove</span><i class="wtn4h"></i></td><td class="GBF9K h2OgJ"><span>Remove</span><i class="wtn4h"></i></td><td class="GBF9K h2OgJ"><span>Remove</span><i class="wtn4h"></i></td><td class="GBF9K h2OgJ"><span>Remove</span><i class="wtn4h"></i></td><td class="GBF9K h2OgJ"><span>Remove</span><i class="wtn4h"></i></td><td class="GBF9K h2OgJ"><span>Remove</span><i class="wtn4h"></i></td><td class="GBF9K h2OgJ"
# ...

# %%
table1=pd.read_html(str(company1))[0]
table1
# Out:
#     Unnamed: 0_level_0                     Unnamed: 1_level_0  \
#                   RANK                      COMPANY/OWNERSHIP
# 0                   10       Reliance IndustriesMukesh Ambani
# 1                 2NEW                                 LICGoI
# 2                   30              Indian Oil CorporationGoI
# 3                   40                                ONGCGoI
# 4                  5-3                 State Bank of IndiaGoI
# ..                 ...                                    ...
# 495             496-14         Usha MartinBrij Kishore Jhawar
# 496             497-95  Godfrey Phillips IndiaK.K. Modi Group
# 497             498NEW               Schwing Stetter IndiaMNC
# 498              499-9                    Hubergroup IndiaMNC
# 499             500NEW         Nitin SpinnersRatan Lal Nolkha
#
#                    Remove                                                \
#     TOTAL INCOME (INR Cr) NET OPERATING INCOME (INR Cr) PROFIT (INR Cr)
# ...

# %%
table1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 17 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   (Unnamed: 0_level_0, RANK)                500 non-null    object
#  1   (Unnamed: 1_level_0, COMPANY/OWNERSHIP)   500 non-null    object
#  2   (Remove, TOTAL INCOME (INR Cr))           500 non-null    object
#  3   (Remove, NET OPERATING INCOME (INR Cr))   500 non-null    object
#  4   (Remove, PROFIT (INR Cr))                 500 non-null    object
#  5   (Remove, Profit as % of Revenue)          500 non-null    object
#  6   (Remove, INTEREST COST / AS % OF EBITDA)  500 non-null    object
#  7   (Remove, cash & bank balance (INR Cr))    500 non-null    int64
#  8   (Remove, total debt (INR Cr))             500 non-null    int64
#  9   (Remove, debt-equity ratio)               500 non-null    object
# ...

# %%
os.getcwd()
# Out:
# 'C:\\Users\\bandu\\python full course'

# %%
table1.to_csv("C:\\Users\\bandu\\python full course\\fortune500",index=False)

# %%
company1=pd.read_csv('fortune500')
company1
# Out:
#     Unnamed: 0_level_0                     Unnamed: 1_level_0  \
# 0                 RANK                      COMPANY/OWNERSHIP
# 1                   10       Reliance IndustriesMukesh Ambani
# 2                 2NEW                                 LICGoI
# 3                   30              Indian Oil CorporationGoI
# 4                   40                                ONGCGoI
# ..                 ...                                    ...
# 496             496-14         Usha MartinBrij Kishore Jhawar
# 497             497-95  Godfrey Phillips IndiaK.K. Modi Group
# 498             498NEW               Schwing Stetter IndiaMNC
# 499              499-9                    Hubergroup IndiaMNC
# 500             500NEW         Nitin SpinnersRatan Lal Nolkha
#
#                     Remove                       Remove.1         Remove.2  \
# 0    TOTAL INCOME (INR Cr)  NET OPERATING INCOME (INR Cr)  PROFIT (INR Cr)
# ...

# %%
company1.columns=[company1.columns,company1.iloc[0]]
company1=company1[1:]
company1.head()
# Out:
#   Unnamed: 0_level_0                Unnamed: 1_level_0                Remove  \
# 0               RANK                 COMPANY/OWNERSHIP TOTAL INCOME (INR Cr)
# 1                 10  Reliance IndustriesMukesh Ambani           73951843.8%
# 2               2NEW                            LICGoI              7247443%
# 3                 30         Indian Oil CorporationGoI             60736562%
# 4                 40                           ONGCGoI           50247454.5%
# 5                5-3            State Bank of IndiaGoI            4069735.6%
#
#                        Remove.1        Remove.2               Remove.3  \
# 0 NET OPERATING INCOME (INR Cr) PROFIT (INR Cr) Profit as % of Revenue
# 1                   69996249.9%      6070523.6%                   8.2%
# 2                    7236064.7%       412538.7%                   0.6%
# 3                   58933661.9%        2510216%                   4.1%
# 4                   49127061.7%     45522179.2%                   9.1%
# ...

# %%
company1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 1 to 500
# Data columns (total 17 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   (Unnamed: 0_level_0, RANK)                  500 non-null    object
#  1   (Unnamed: 1_level_0, COMPANY/OWNERSHIP)     500 non-null    object
#  2   (Remove, TOTAL INCOME (INR Cr))             500 non-null    object
#  3   (Remove.1, NET OPERATING INCOME (INR Cr))   500 non-null    object
#  4   (Remove.2, PROFIT (INR Cr))                 500 non-null    object
#  5   (Remove.3, Profit as % of Revenue)          500 non-null    object
#  6   (Remove.4, INTEREST COST / AS % OF EBITDA)  500 non-null    object
#  7   (Remove.5, cash & bank balance (INR Cr))    500 non-null    object
#  8   (Remove.6, total debt (INR Cr))             500 non-null    object
#  9   (Remove.7, debt-equity ratio)               500 non-null    object
# ...

# %%
company1.isnull().sum()
# Out:
# Unnamed: 0_level_0  RANK                              0
# Unnamed: 1_level_0  COMPANY/OWNERSHIP                 0
# Remove              TOTAL INCOME (INR Cr)             0
# Remove.1            NET OPERATING INCOME (INR Cr)     0
# Remove.2            PROFIT (INR Cr)                   0
# Remove.3            Profit as % of Revenue            0
# Remove.4            INTEREST COST / AS % OF EBITDA    0
# Remove.5            cash & bank balance (INR Cr)      0
# Remove.6            total debt (INR Cr)               0
# Remove.7            debt-equity ratio                 0
# Remove.8            TOTAL ASSETS (INR Cr)             0
# Remove.9            NET WORTH (INR Cr)                0
# Remove.10           RONW%                             0
# Remove.11           ROCE%                             0
# Remove.12           EMPLOYEES (IN NOS.)               0
# Remove.13           T12M AVG M-CAP (INR Cr)           0
# Remove.14           TSR%                              0
# ...

# %%
company1['Unnamed: 0_level_0']=company1['Unnamed: 0_level_0'].fillna(0)
# Out:
# C:\Users\bandu\AppData\Local\Temp\ipykernel_23720\3021658483.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   company1['Unnamed: 0_level_0']=company1['Unnamed: 0_level_0'].fillna(0)

# %%
company1['Unnamed: 0_level_0']
# Out:
# 0      RANK
# 1        10
# 2      2NEW
# 3        30
# 4        40
# 5       5-3
# ..      ...
# 496  496-14
# 497  497-95
# 498  498NEW
# 499   499-9
# 500  500NEW
#
# [500 rows x 1 columns]

# %%
company1['Unnamed: 0_level_0'].isnull().sum()
# Out:
# 0
# RANK    0
# dtype: int64

# %%
company1.to_csv("C:\\Users\\bandu\\python full course\\fortune500 2.0",index=False)

# %%
df1=pd.read_csv('fortune500 2.0')

# %%
df1
# Out:
#     Unnamed: 0_level_0                     Unnamed: 1_level_0  \
# 0                 RANK                      COMPANY/OWNERSHIP
# 1                   10       Reliance IndustriesMukesh Ambani
# 2                 2NEW                                 LICGoI
# 3                   30              Indian Oil CorporationGoI
# 4                   40                                ONGCGoI
# ..                 ...                                    ...
# 496             496-14         Usha MartinBrij Kishore Jhawar
# 497             497-95  Godfrey Phillips IndiaK.K. Modi Group
# 498             498NEW               Schwing Stetter IndiaMNC
# 499              499-9                    Hubergroup IndiaMNC
# 500             500NEW         Nitin SpinnersRatan Lal Nolkha
#
#                     Remove                       Remove.1         Remove.2  \
# 0    TOTAL INCOME (INR Cr)  NET OPERATING INCOME (INR Cr)  PROFIT (INR Cr)
# ...

# %%
df1=df1.drop(columns=['Unnamed: 0_level_0','Remove.4', 'Remove.13', 'Remove.14'])

# %%
df1=df1.drop(0)

# %%
df1
# Out:
#                         Unnamed: 1_level_0       Remove     Remove.1  \
# 1         Reliance IndustriesMukesh Ambani  73951843.8%  69996249.9%
# 2                                   LICGoI     7247443%   7236064.7%
# 3                Indian Oil CorporationGoI    60736562%  58933661.9%
# 4                                  ONGCGoI  50247454.5%  49127061.7%
# 5                   State Bank of IndiaGoI   4069735.6%   2899734.3%
# ..                                     ...          ...          ...
# 496         Usha MartinBrij Kishore Jhawar    281232.9%    268828.2%
# 497  Godfrey Phillips IndiaK.K. Modi Group     28122.4%     27066.4%
# 498               Schwing Stetter IndiaMNC    280186.8%    253962.6%
# 499                    Hubergroup IndiaMNC      2797NAP      2695NAP
# 500         Nitin SpinnersRatan Lal Nolkha    278868.8%    269265.7%
#
#         Remove.2 Remove.3 Remove.5 Remove.6 Remove.7      Remove.8 Remove.9  \
# ...

# %%
df1.columns
# Out:
# Index(['Unnamed: 1_level_0', 'Remove', 'Remove.1', 'Remove.2', 'Remove.3',
#        'Remove.5', 'Remove.6', 'Remove.7', 'Remove.8', 'Remove.9', 'Remove.10',
#        'Remove.11', 'Remove.12'],
#       dtype='object')

# %%
new_columns1={'Unnamed: 1_level_0':'Company/Ownership1','Remove':'Total_income(INR)1','Remove.1':'Net_income(INR)1','Remove.2':'Profit(INR)1','Remove.3':'Profit % of Revenue1','Remove.5':'Cash & Bank balance1','Remove.6':'Total Debt1','Remove.7':'Debt equity ratio1','Remove.8':'Total Assets1','Remove.9':'Net worth1','Remove.10':'RONW1','Remove.11':'ROCE1','Remove.12':'Employees1'}

# %%
df1.rename(columns=new_columns1,inplace=True)

# %%
df1
# Out:
#                         Company/Ownership1 Total_income(INR)1  \
# 1         Reliance IndustriesMukesh Ambani        73951843.8%
# 2                                   LICGoI           7247443%
# 3                Indian Oil CorporationGoI          60736562%
# 4                                  ONGCGoI        50247454.5%
# 5                   State Bank of IndiaGoI         4069735.6%
# ..                                     ...                ...
# 496         Usha MartinBrij Kishore Jhawar          281232.9%
# 497  Godfrey Phillips IndiaK.K. Modi Group           28122.4%
# 498               Schwing Stetter IndiaMNC          280186.8%
# 499                    Hubergroup IndiaMNC            2797NAP
# 500         Nitin SpinnersRatan Lal Nolkha          278868.8%
#
#     Net_income(INR)1 Profit(INR)1 Profit % of Revenue1 Cash & Bank balance1  \
# 1        69996249.9%   6070523.6%                 8.2%                36178
# ...

# %%
df
# Out:
#                                       Company/Ownership              Industry  \
# Rank
# 1                      Reliance IndustriesMukesh Ambani             Oil & Gas
# 2                                      LICGovt of India      Insurance - Life
# 3                   Indian Oil CorporationGovt of India             Oil & Gas
# 4                      State Bank of IndiaGovt of India                 Banks
# 5                                     ONGCGovt of India             Oil & Gas
# ...                                                 ...                   ...
# 496                       Route MobileS.K. & R.K. Gupta           IT Services
# 497        Himadri Speciality ChemicalSadashiv K Shetty  Speciality Chemicals
# 498   Rajasthan Rajya Vidyut Prasaran Nigam ^Govt of...                 Power
# 499              Indo Rama Synthetics (India)O.P. Lohia              Textiles
# 500                             Tetra-Pak India ^^ ^MNC                 Paper
#
# ...

# %%
df=df.drop(columns=['Industry','Marketcap'])
df
# Out:
#                                       Company/Ownership  Total_income(INR)  \
# Rank
# 1                      Reliance IndustriesMukesh Ambani            9977958
# 2                                      LICGovt of India            8934653
# 3                   Indian Oil CorporationGovt of India            7660081
# 4                      State Bank of IndiaGovt of India           66334311
# 5                                     ONGCGovt of India            6248050
# ...                                                 ...                ...
# 496                       Route MobileS.K. & R.K. Gupta             467213
# 497        Himadri Speciality ChemicalSadashiv K Shetty              46699
# 498   Rajasthan Rajya Vidyut Prasaran Nigam ^Govt of...              46346
# 499              Indo Rama Synthetics (India)O.P. Lohia             462915
# 500                             Tetra-Pak India ^^ ^MNC              46298
#
# ...

# %%
df1.index.name = 'Rank'

# %%
df1
# Out:
#                          Company/Ownership1 Total_income(INR)1  \
# Rank
# 1          Reliance IndustriesMukesh Ambani        73951843.8%
# 2                                    LICGoI           7247443%
# 3                 Indian Oil CorporationGoI          60736562%
# 4                                   ONGCGoI        50247454.5%
# 5                    State Bank of IndiaGoI         4069735.6%
# ...                                     ...                ...
# 496          Usha MartinBrij Kishore Jhawar          281232.9%
# 497   Godfrey Phillips IndiaK.K. Modi Group           28122.4%
# 498                Schwing Stetter IndiaMNC          280186.8%
# 499                     Hubergroup IndiaMNC            2797NAP
# 500          Nitin SpinnersRatan Lal Nolkha          278868.8%
#
#      Net_income(INR)1 Profit(INR)1 Profit % of Revenue1 Cash & Bank balance1  \
# Rank
# 1         69996249.9%   6070523.6%                 8.2%                36178
# ...

# %%
df1.columns = [col.strip() for col in df1.columns]

# %%
percent_columns = [
    'Total_income(INR)1', 'Net_income(INR)1', 'Profit(INR)1', 
    'Profit % of Revenue1', 'Total Assets1', 'RONW1', 'ROCE1'
]

# 2. Loop through each column to remove % and convert to numeric
for col in percent_columns:
    # We use .str.replace to remove the %
    # We also use .str.replace(',', '') just in case there are thousands separators
    # We use .strip() to remove any hidden leading/trailing spaces
    df1[col] = df1[col].astype(str).str.replace('%', '').str.replace(',', '').str.replace(r'[a-zA-Z]', '', regex=True).str.replace(r'[^0-9.]', '', regex=True).str.strip()
    
    # 3. Convert the column to a numeric float
    # errors='coerce' will turn any non-numeric leftovers (like 'NAP') into NaN
    df1[col] = pd.to_numeric(df1[col], errors='coerce')

# Check the result
print("New Data Types:")
print(df1[percent_columns].dtypes)
print("\nCleaned Data Preview:")
print(df1[percent_columns].head())
# Out:
# New Data Types:
# Total_income(INR)1      float64
# Net_income(INR)1        float64
# Profit(INR)1            float64
# Profit % of Revenue1    float64
# Total Assets1           float64
# RONW1                   float64
# ROCE1                   float64
# dtype: object
#
# Cleaned Data Preview:
#       Total_income(INR)1  Net_income(INR)1  Profit(INR)1  \
# Rank
# 1             73951843.8        69996249.9     6070523.6
# 2              7247443.0         7236064.7      412538.7
# 3             60736562.0        58933661.9     2510216.0
# 4             50247454.5        49127061.7    45522179.2
# 5              4069735.6         2899734.3     3537457.9
#
#       Profit % of Revenue1  Total Assets1  RONW1  ROCE1
# Rank
# 1                      8.2    122262711.5    9.2    9.4
# 2                      0.6    418253611.6   45.3    0.3
# 3                      4.1     27285216.4   21.0   15.3
# 4                      9.1      4444896.1   20.5   14.6
# ...

# %%
print(df1['Profit(INR)1'].unique())
# Out:
# [6.07052360e+06 4.12538700e+05 2.51021600e+06 4.55221792e+07
#  3.53745790e+06 1.16822770e+06 1.14410000e+04 4.01544361e+07
#  1.37302942e+07 3.83271820e+06 3.80531950e+06 8.66925200e+05
#  2.51103660e+06 2.06651612e+07 2.25952060e+06 1.66761400e+06
#  1.88026210e+06 2.21101430e+06 4.25520000e+04 1.73583670e+06
#  1.22431952e+07 7.55075400e+05 9.21101000e+05 1.22569970e+06
#  6.57726290e+06 6.12511190e+06 3.88011600e+05 3.86150700e+05
#  7.85040720e+06 1.34992110e+06 1.41199620e+06 5.26583900e+05
#  1.22301330e+06 1.40151930e+06 4.55719000e+04 8.74159000e+04
#  1.52431580e+06 1.20892100e+06 8.04103000e+04 7.34434400e+05
#  8.87911100e+05 5.75358300e+05 2.38619800e+05 2.90254200e+05
#  3.62626300e+05 3.49367700e+05 1.68243980e+06 1.74154500e+05
#  4.14231500e+05 5.56625700e+05 3.43817000e+05 3.27312700e+05
#  1.00361980e+06 2.82450000e+04 4.80564000e+05 5.17918100e+05
#  1.95881000e+04 6.16627000e+05 2.17312330e+06 4.91228670e+06
# ...

# %%
df1['Total_income(INR)1'] = df1['Total_income(INR)1'].fillna(0).astype(int)

# %%
df1['Net_income(INR)1'] = df1['Net_income(INR)1'].fillna(0).astype(int)

# %%
df1['Profit(INR)1']=df1['Profit(INR)1'].fillna(0).astype(int)

# %%
df1['Profit % of Revenue1']=df1['Profit % of Revenue1'].fillna(0).astype(int)

# %%
df1['Total Assets1']=df1['Total Assets1'].fillna(0).astype(int)

# %%
df1['RONW1']=df1['RONW1'].fillna(0).astype(int)

# %%
df1['ROCE1']=df1['ROCE1'].fillna(0).astype(int)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 1 to 500
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Company/Ownership1    500 non-null    object
#  1   Total_income(INR)1    500 non-null    int32
#  2   Net_income(INR)1      500 non-null    int32
#  3   Profit(INR)1          500 non-null    int32
#  4   Profit % of Revenue1  500 non-null    int32
#  5   Cash & Bank balance1  500 non-null    object
#  6   Total Debt1           500 non-null    object
#  7   Debt equity ratio1    500 non-null    object
#  8   Total Assets1         500 non-null    int32
#  9   Net worth1            500 non-null    object
#  10  RONW1                 500 non-null    int32
#  11  ROCE1                 500 non-null    int32
#  12  Employees1            500 non-null    object
# dtypes: int32(7), object(6)
# memory usage: 37.2+ KB

# %%
df1['Cash & Bank balance1'] = df1['Cash & Bank balance1'].astype(str).str.replace(r'[^0-9.-]', '', regex=True)

# 2. Convert to numeric
df1['Cash & Bank balance1'] = pd.to_numeric(df1['Cash & Bank balance1'], errors='coerce')

# 3. Fill any empty spots (like where 'NAP' was) with 0
df1['Cash & Bank balance1'] = df1['Cash & Bank balance1'].fillna(0)

# Now run describe again - it will look totally different!
print(df1['Cash & Bank balance1'].describe())
# Out:
# count       500.000000
# mean       6441.924000
# std       26227.705723
# min           1.000000
# 25%         178.750000
# 50%         621.000000
# 75%        2667.000000
# max      398905.000000
# Name: Cash & Bank balance1, dtype: float64

# %%
cols_to_convert1 = ['Total Debt1', 'Debt equity ratio1', 'Employees1','Net worth1']

for col in cols_to_convert1:
    # Remove everything except numbers, dots, and minus signs
    # This cleans up commas, currency symbols, and spaces in one go
    df1[col] = df1[col].astype(str).str.replace(r'[^0-9.-]', '', regex=True)
    
    # Convert the cleaned strings to actual floats
    # 'coerce' turns remaining text like "NAP" into NaN
    df1[col] = pd.to_numeric(df1[col], errors='coerce')
    
    # Fill empty spots with 0 to keep the data consistent
    df1[col] = df1[col].fillna(0)

# 2. Now verify that they are all numerical
print(df1[cols_to_convert1].info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 1 to 500
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Total Debt1         500 non-null    int64
#  1   Debt equity ratio1  500 non-null    float64
#  2   Employees1          500 non-null    float64
#  3   Net worth1          500 non-null    int64
# dtypes: float64(2), int64(2)
# memory usage: 15.8 KB
# None

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 1 to 500
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Company/Ownership1    500 non-null    object
#  1   Total_income(INR)1    500 non-null    int32
#  2   Net_income(INR)1      500 non-null    int32
#  3   Profit(INR)1          500 non-null    int32
#  4   Profit % of Revenue1  500 non-null    int32
#  5   Cash & Bank balance1  500 non-null    int64
#  6   Total Debt1           500 non-null    int64
#  7   Debt equity ratio1    500 non-null    float64
#  8   Total Assets1         500 non-null    int32
#  9   Net worth1            500 non-null    int64
#  10  RONW1                 500 non-null    int32
#  11  ROCE1                 500 non-null    int32
#  12  Employees1            500 non-null    float64
# dtypes: float64(2), int32(7), int64(3), object(1)
# memory usage: 37.2+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 1 to 500
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Company/Ownership    500 non-null    object
#  1   Total_income(INR)    500 non-null    int32
#  2   Net_income(INR)      500 non-null    int32
#  3   Profit(INR)          500 non-null    int32
#  4   Profit % of Revenue  500 non-null    int32
#  5   Cash & Bank balance  500 non-null    int64
#  6   Total Debt           500 non-null    int64
#  7   Debt equity ratio    500 non-null    float64
#  8   Total Assets         500 non-null    int32
#  9   Net worth            500 non-null    int64
#  10  RONW                 500 non-null    int32
#  11  ROCE                 500 non-null    int32
#  12  Employees            500 non-null    float64
# dtypes: float64(2), int32(7), int64(3), object(1)
# memory usage: 37.2+ KB

# %%
correlation_matrix = df.select_dtypes(include=['number']).corr()
print(correlation_matrix)
# Out:
#                      Total_income(INR)  Net_income(INR)  Profit(INR)  \
# Total_income(INR)             1.000000         0.851382     0.282359
# Net_income(INR)               0.851382         1.000000     0.250916
# Profit(INR)                   0.282359         0.250916     1.000000
# Profit % of Revenue           0.221384         0.006841     0.252159
# Cash & Bank balance           0.609325         0.651390     0.214916
# Total Debt                    0.657904         0.685285     0.206966
# Debt equity ratio             0.012634         0.026141     0.047185
# Total Assets                  0.379680         0.440688     0.231391
# Net worth                     0.529039         0.577469     0.193592
# RONW                          0.460356         0.035030     0.009450
# ROCE                         -0.075063        -0.048009    -0.034439
# Employees                     0.316856         0.376749     0.119424
#
# ...

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Fortune 500 Correlation Heatmap (2025)')
plt.show()

# %%
correlation_matrix1 = df1.select_dtypes(include=['number']).corr()
print(correlation_matrix1)
# Out:
#                       Total_income(INR)1  Net_income(INR)1  Profit(INR)1  \
# Total_income(INR)1              1.000000          0.933692      0.416920
# Net_income(INR)1                0.933692          1.000000      0.373326
# Profit(INR)1                    0.416920          0.373326      1.000000
# Profit % of Revenue1            0.112336         -0.038944      0.235902
# Cash & Bank balance1            0.075587          0.067006      0.096565
# Total Debt1                     0.063828          0.054026      0.084130
# Debt equity ratio1             -0.013642         -0.015442     -0.014696
# Total Assets1                   0.144131          0.129471      0.079816
# Net worth1                      0.674302          0.701715      0.287344
# RONW1                           0.074768          0.059573      0.304008
# ROCE1                           0.032647          0.020881      0.002489
# Employees1                      0.390037          0.406054      0.120092
#
# ...

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix1, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Fortune 500 Correlation Heatmap (2022)')
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 1 to 500
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Company/Ownership    500 non-null    object
#  1   Total_income(INR)    500 non-null    int32
#  2   Net_income(INR)      500 non-null    int32
#  3   Profit(INR)          500 non-null    int32
#  4   Profit % of Revenue  500 non-null    int32
#  5   Cash & Bank balance  500 non-null    int64
#  6   Total Debt           500 non-null    int64
#  7   Debt equity ratio    500 non-null    float64
#  8   Total Assets         500 non-null    int32
#  9   Net worth            500 non-null    int64
#  10  RONW                 500 non-null    int32
#  11  ROCE                 500 non-null    int32
#  12  Employees            500 non-null    float64
# dtypes: float64(2), int32(7), int64(3), object(1)
# memory usage: 37.2+ KB

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 1 to 500
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Company/Ownership1    500 non-null    object
#  1   Total_income(INR)1    500 non-null    int32
#  2   Net_income(INR)1      500 non-null    int32
#  3   Profit(INR)1          500 non-null    int32
#  4   Profit % of Revenue1  500 non-null    int32
#  5   Cash & Bank balance1  500 non-null    int64
#  6   Total Debt1           500 non-null    int64
#  7   Debt equity ratio1    500 non-null    float64
#  8   Total Assets1         500 non-null    int32
#  9   Net worth1            500 non-null    int64
#  10  RONW1                 500 non-null    int32
#  11  ROCE1                 500 non-null    int32
#  12  Employees1            500 non-null    float64
# dtypes: float64(2), int32(7), int64(3), object(1)
# memory usage: 37.2+ KB

# %%
# We'll pick a few key columns to keep the graph readable
key_cols = ['Profit(INR)', 'Cash & Bank balance', 'Total Assets', 'Total Debt']
sns.pairplot(df[key_cols], diag_kind='kde')
plt.suptitle('Pairwise Relationships of Key Metrics', y=1.02)
plt.show()
# Out:
# C:\Users\bandu\anaconda3\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# Merge the two dataframes
# df1 is your 2022 data, df2 is your 2025 data
merged_df = pd.merge(
    df[['Company/Ownership', 'Total_income(INR)']], 
    df1[['Company/Ownership1', 'Total_income(INR)1']], 
    left_on='Company/Ownership', 
    right_on='Company/Ownership1'
)

# Pick Top 10 by 2025 income to keep the graph readable
top_10 = merged_df.sort_values(by='Total_income(INR)1', ascending=False).head(10)

# %%
# Create a 'long' format version for the bar plot
plot_data = top_10.melt(
    id_vars='Company/Ownership', 
    value_vars=['Total_income(INR)', 'Total_income(INR)1'],
    var_name='Year_Source', 
    value_name='Income_Value'
)

# Rename the labels for the legend
plot_data['Year'] = plot_data['Year_Source'].map({
    'Total_income(INR)': '2022', 
    'Total_income(INR)1': '2025'
})

# %%
plt.figure(figsize=(12, 8))
sns.barplot(
    data=plot_data, 
    x='Income_Value', 
    y='Company/Ownership', 
    hue='Year', 
    palette='viridis'
)

plt.title('Comparison of Total Income (INR): 2022 vs 2025 (Top 10 Companies)')
plt.xlabel('Income in INR')
plt.ylabel('Company Name')
plt.legend(title='Year')
plt.tight_layout()
plt.show()

# %%
# Calculate the Change
merged_df = pd.merge(df, df1, left_on='Company/Ownership', right_on='Company/Ownership1')
merged_df['Income_Growth'] = merged_df['Total_income(INR)1'] - merged_df['Total_income(INR)']

# Plot the Top 10 Gainers
top_gainers = merged_df.sort_values(by='Income_Growth', ascending=False).head(10)

plt.figure(figsize=(12, 6))
sns.barplot(data=top_gainers, x='Income_Growth', y='Company/Ownership', palette='Greens_r')
plt.title('Top 10 Companies by Income Growth (2022 to 2025)', fontsize=14)
plt.xlabel('Increase in Total Income (INR)')
plt.show()

# %%
plt.figure(figsize=(8, 8))
# Use Profit or Total Income
sns.scatterplot(data=merged_df, x='Profit(INR)', y='Profit(INR)1', alpha=0.6)

# Add the 1:1 "Line of No Change"
max_val = max(merged_df['Profit(INR)'].max(), merged_df['Profit(INR)1'].max())
plt.plot([0, max_val], [0, max_val], color='red', linestyle='--')

plt.title('Profit Comparison: 2022 vs 2025', fontsize=14)
plt.xlabel('Profit in 2022 (INR)')
plt.ylabel('Profit in 2025 (INR)')
plt.show()

# %%
# Create a temporary dataframe for distribution comparison
dist_df = pd.DataFrame({
    'Profit Margin (%)': pd.concat([df1['Profit % of Revenue1'], df['Profit % of Revenue']]),
    'Year': ['2022']*500 + ['2025']*500
})

plt.figure(figsize=(10, 6))
sns.boxplot(data=dist_df, x='Year', y='Profit Margin (%)', palette='Set2')
plt.title('Shift in Profitability Margins across the Fortune 500', fontsize=14)
plt.show()

# %%
plt.figure(figsize=(12, 7))
sns.scatterplot(data=df, x='Total_income(INR)', y='ROCE', size='Employees', sizes=(20, 500), alpha=0.5)
plt.title('2025: Total Income vs. Efficiency (ROCE)', fontsize=14)
plt.xlabel('Scale (Total Income)')
plt.ylabel('Efficiency (ROCE %)')
plt.show()

# %%
# 1. Merge and Calculate Difference
merged_emp = pd.merge(
    df[['Company/Ownership', 'Employees']], 
    df1[['Company/Ownership1', 'Employees1']], 
    left_on='Company/Ownership', 
    right_on='Company/Ownership1'
)

# Calculate the Change in Employee count
merged_emp['Employee_Change'] = merged_emp['Employees1'] - merged_emp['Employees']

# 2. Plot Top 10 Gainers
top_hiring = merged_emp.sort_values(by='Employee_Change', ascending=False).head(10)

plt.figure(figsize=(12, 6))
sns.barplot(data=top_hiring, x='Employee_Change', y='Company/Ownership', palette='Blues_r')
plt.title('Top 10 Companies by Employee Growth (2022-2025)', fontsize=14)
plt.xlabel('Increase in Number of Employees')
plt.show()

# %%
plt.figure(figsize=(10, 6))
# Plotting the distribution of Total Income for 2025
sns.histplot(df1['Total_income(INR)1'], bins=30, kde=True, color='purple')

plt.title('Distribution of Total Income (2025)', fontsize=14)
plt.xlabel('Total Income (INR)')
plt.ylabel('Number of Companies')
plt.show()

# %%
# 1. Sort and split the data
top_10 = df1.sort_values(by='Total_income(INR)1', ascending=False).head(10)
others_val = df1.sort_values(by='Total_income(INR)1', ascending=False).iloc[10:]['Total_income(INR)1'].sum()

# 2. Prepare labels and values
labels = top_10['Company/Ownership1'].tolist() + ['Others']
values = top_10['Total_income(INR)1'].tolist() + [others_val]

# 3. Plotting
plt.figure(figsize=(12, 8))
colors = sns.color_palette('pastel')[0:11]

plt.pie(values, labels=labels, autopct='%1.1f%%', startangle=140, colors=colors, explode=[0.1 if i < 3 else 0 for i in range(11)])
plt.title('Market Share by Company: Total Income 2025', fontsize=15)
plt.tight_layout()
plt.show()

# %%
# 1. Sort and split the data
top_10 = df.sort_values(by='Total_income(INR)', ascending=False).head(10)
others_val = df.sort_values(by='Total_income(INR)', ascending=False).iloc[10:]['Total_income(INR)'].sum()

# 2. Prepare labels and values
labels = top_10['Company/Ownership'].tolist() + ['Others']
values = top_10['Total_income(INR)'].tolist() + [others_val]

# 3. Plotting
plt.figure(figsize=(12, 8))
colors = sns.color_palette('pastel')[0:11]

plt.pie(values, labels=labels, autopct='%1.1f%%', startangle=140, colors=colors, explode=[0.1 if i < 3 else 0 for i in range(11)])
plt.title('Market Share by Company: Total Income 2025', fontsize=15)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 6))
# Create the histogram
ax = sns.histplot(df1['Employees1'], bins=15, color='skyblue', kde=False)

# Add the count labels on top of each bar
for p in ax.patches:
    ax.annotate(f'{int(p.get_height())}', (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha='center', va='center', fontsize=10, color='black', xytext=(0, 7), 
                textcoords='offset points')

plt.title('Frequency of Company Sizes by Employee Count (2025)', fontsize=14)
plt.xlabel('Number of Employees')
plt.ylabel('Number of Companies')
plt.show()

# %%
plt.figure(figsize=(12, 6))
# Create the histogram
ax = sns.histplot(df['Employees'], bins=15, color='skyblue', kde=False)

# Add the count labels on top of each bar
for p in ax.patches:
    ax.annotate(f'{int(p.get_height())}', (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha='center', va='center', fontsize=10, color='black', xytext=(0, 7), 
                textcoords='offset points')

plt.title('Frequency of Company Sizes by Employee Count (2025)', fontsize=14)
plt.xlabel('Number of Employees')
plt.ylabel('Number of Companies')
plt.show()

# %%
# 1. Select Top 10 companies by Total Assets for 2025
top_10_assets = df1.sort_values(by='Total Assets1', ascending=False).head(10)

# 2. Plotting
plt.figure(figsize=(4, 4))

# Create the "bottom" part of the bar (Net Worth)
plt.barh(top_10_assets['Company/Ownership1'], top_10_assets['Net worth1'], 
         label='Net Worth (Equity)', color='#2ecc71')

# Create the "stacked" part (Total Debt) starting from the end of Net Worth
plt.barh(top_10_assets['Company/Ownership1'], top_10_assets['Total Debt1'], 
         left=top_10_assets['Net worth1'], label='Total Debt', color='#e74c3c')

plt.title('Capital Structure of Top 10 Companies (2025): Debt vs. Net Worth', fontsize=16)
plt.xlabel('Value (in INR)')
plt.ylabel('Company Name')
plt.legend(loc='lower right')

# Optional: Add the Total Asset value as a text label at the end of the bar
for i, (assets, company) in enumerate(zip(top_10_assets['Total Assets1'], top_10_assets['Company/Ownership1'])):
    plt.text(assets, i, f' {assets:,}', va='center', fontsize=10, fontweight='bold')

plt.grid(axis='x', linestyle='--', alpha=0.4)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\bandu\AppData\Local\Temp\ipykernel_23720\2224884201.py:25: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 1. Prepare data (Top 10 by Assets)
top_10_assets = df1.sort_values(by='Total Assets1', ascending=False).head(10)

# Set the visual style
sns.set_theme(style="whitegrid")
plt.figure(figsize=(16, 8))

# 2. Plot Total Assets first (This will act as the "back" layer)
# Since Assets = Net Worth + Debt, this bar represents the full length
sns.barplot(
    data=top_10_assets, 
    x='Total Assets1', 
    y='Company/Ownership1', 
    color='#e74c3c', 
    label='Total Debt'
)

# 3. Plot Net Worth second (This will overlap the back layer)
sns.barplot(
    data=top_10_assets, 
    x='Net worth1', 
    y='Company/Ownership1', 
    color='#2ecc71', 
    label='Net Worth (Equity)'
)

# 4. Final touches
plt.title('Capital Structure (Seaborn): Debt vs. Net Worth (2025)', fontsize=16)
plt.xlabel('Value (in INR)')
plt.ylabel('Company Name')
plt.legend(ncol=2, loc="lower right", frameon=True)

# 5. Adding the total value labels (Using the same logic as before)
for i, row in enumerate(top_10_assets.itertuples()):
    plt.text(row._8 + (row._8 * 0.01), i, f'{row._8:,}', 
             va='center', fontsize=10, fontweight='bold')

sns.despine(left=True, bottom=True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.regplot(data=df1, x='Total Assets1', y='Total Debt1', 
            scatter_kws={'alpha':0.5, 'color':'#34495e'}, line_kws={'color':'red'})

plt.title('Relationship: Total Assets vs. Total Debt (2025)', fontsize=14)
plt.xlabel('Total Assets (INR)')
plt.ylabel('Total Debt (INR)')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 1. Prepare data (Top 10 by Assets)
top_10_assets = df.sort_values(by='Total Assets', ascending=False).head(10)

# Set the visual style
sns.set_theme(style="whitegrid")
plt.figure(figsize=(14, 8))

# 2. Plot Total Assets first (This will act as the "back" layer)
# Since Assets = Net Worth + Debt, this bar represents the full length
sns.barplot(
    data=top_10_assets, 
    x='Total Assets', 
    y='Company/Ownership', 
    color='#e74c3c', 
    label='Total Debt'
)

# 3. Plot Net Worth second (This will overlap the back layer)
sns.barplot(
    data=top_10_assets, 
    x='Net worth', 
    y='Company/Ownership', 
    color='#2ecc71', 
    label='Net Worth (Equity)'
)

# 4. Final touches
plt.title('Capital Structure (Seaborn): Debt vs. Net Worth (2025)', fontsize=16)
plt.xlabel('Value (in INR)')
plt.ylabel('Company Name')
plt.legend(ncol=2, loc="lower right", frameon=True)

# 5. Adding the total value labels (Using the same logic as before)
for i, row in enumerate(top_10_assets.itertuples()):
    plt.text(row._8 + (row._8 * 0.01), i, f'{row._8:,}', 
             va='center', fontsize=10, fontweight='bold')

sns.despine(left=True, bottom=True)
plt.tight_layout()
plt.show()
